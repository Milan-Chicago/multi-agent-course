# %% [markdown]
# # Python Readiness Exam (MLE / Data Science Entry)
#
# **Time:** 60–75 minutes
# **Rules:** No internet. Standard Python only (no pandas, numpy).
# **How to submit:** Run all cells, then export this notebook as **HTML** or **PDF** if required by your instructor.
#
# ---
#
# ## Instructions
# - Answer each question in the cell directly below it.
# - Do **not** change the question text.
# - Keep your solutions clear and readable.
# - Unless stated otherwise, assume inputs are valid.
#
# **Tip:** You may create helper variables and print intermediate values while working.

# %% [markdown]
# ## 1) Variable & Type Understanding
#
# Given the code below:
#
# ```python
# x = "10"
# y = 5
# print(x * y)
# ```
#
# **Question:** What is the output and why?

# %%
# Write your answer here (in text), then run this cell if you'd like to confirm output.
x = "10"
y = 5
print(x * y)

# %% [markdown]
# ## 2) Type Conversion
#
# Write a function that takes a string number and returns it as an integer.
#
# **Requirement:** Use `int()` appropriately.

# %%
def to_int(s):
    """Convert string s to an integer."""
    # TODO: implement
    pass

# %%
# Quick check (optional)
# print(to_int("42"))  # should print 42

# %% [markdown]
# ## 3) Boolean Logic
#
# What does this print?
#
# ```python
# print(5 > 3 and 2 < 1 or 4 == 4)
# ```
# Explain your reasoning in 1–2 sentences.

# %%
# Write your explanation above (markdown cell if you want).
print(5 > 3 and 2 < 1 or 4 == 4)

# %% [markdown]
# ## 4) Conditional Logic
#
# Write a function that returns:
# - `"High"` if `score` is > 80
# - `"Medium"` if `score` is between 50 and 80 (inclusive)
# - `"Low"` otherwise

# %%
def categorize(score):
    """Return 'High', 'Medium', or 'Low' based on score."""
    # TODO: implement
    pass

# %%
# Quick checks (optional)
# print(categorize(90))  # High
# print(categorize(80))  # Medium
# print(categorize(10))  # Low

# %% [markdown]
# ## 5) Loop Reasoning
#
# What is printed?
#
# ```python
# for i in range(1, 6):
#     if i % 2 == 0:
#         continue
#     print(i)
# ```
# Explain briefly.

# %%
for i in range(1, 6):
    if i % 2 == 0:
        continue
    print(i)

# %% [markdown]
# ## 6) While Loop
#
# Write a function that sums numbers from 1 up to `n` (inclusive).
#
# Example: `sum_up_to(5)` returns `15`.

# %%
def sum_up_to(n):
    """Sum integers from 1 to n inclusive."""
    # TODO: implement using a while loop
    pass

# %%
# Quick checks (optional)
# print(sum_up_to(5))  # 15

# %% [markdown]
# ## 7) Lists
#
# Given:
#
# ```python
# nums = [1, 2, 3, 4, 5]
# ```
#
# Write code that returns a **new list** containing only the even numbers.

# %%
nums = [1, 2, 3, 4, 5]
# TODO: create a new list of even numbers
even_nums = None

# print(even_nums)  # should be [2, 4]

# %% [markdown]
# ## 8) Dictionaries
#
# Given:
#
# ```python
# data = {"a": 10, "b": 20, "c": 30}
# ```
#
# Write a function that returns the key with the **largest value**.

# %%
def max_key(d):
    """Return the key in dict d with the largest associated value."""
    # TODO: implement
    pass

# %%
# Quick check (optional)
# data = {"a": 10, "b": 20, "c": 30}
# print(max_key(data))  # c

# %% [markdown]
# ## 9) Sets
#
# What is the output?
#
# ```python
# a = {1, 2, 3}
# b = {3, 4, 5}
# print(a & b)
# ```
#
# Explain what operation is being performed.

# %%
a = {1, 2, 3}
b = {3, 4, 5}
print(a & b)

# %% [markdown]
# ## 10) List Comprehension
#
# Rewrite the following using a list comprehension:
#
# ```python
# squares = []
# for i in range(1, 6):
#     squares.append(i ** 2)
# ```

# %%
# TODO: rewrite using a list comprehension
squares = None

# print(squares)  # should be [1, 4, 9, 16, 25]

# %% [markdown]
# ## 11) Default Arguments
#
# What does this print? Why is it a common pitfall?
#
# ```python
# def add_item(item, lst=[]):
#     lst.append(item)
#     return lst
#
# print(add_item(1))
# print(add_item(2))
# ```

# %%
def add_item(item, lst=[]):
    lst.append(item)
    return lst

print(add_item(1))
print(add_item(2))

# %% [markdown]
# ## 12) String Manipulation
#
# Write a function that counts how many times a character `c` appears in string `s`.
#
# Example: `char_count("banana", "a")` returns `3`.

# %%
def char_count(s, c):
    """Count occurrences of character c in string s."""
    # TODO: implement
    pass

# %%
# Quick checks (optional)
# print(char_count("banana", "a"))  # 3

# %% [markdown]
# ## 13) Splitting & Parsing
#
# Given:
#
# ```python
# text = "apple,banana,orange"
# ```
#
# Write code to turn this into a Python list of words: `["apple", "banana", "orange"]`.

# %%
text = "apple,banana,orange"
# TODO: split into a list
words = None

# print(words)  # ["apple", "banana", "orange"]

# %% [markdown]
# ## 14) Debug the Code
#
# This function should return the average of a list of numbers. Fix it.
#
# ```python
# def average(nums):
#     total = 0
#     for n in nums:
#         total += n
#     return total / len(n)
# ```

# %%
def average(nums):
    total = 0
    for n in nums:
        total += n
    # TODO: fix the bug(s) below
    return total / len(n)

# %%
# Quick checks (optional)
# print(average([1, 2, 3]))  # 2.0

# %% [markdown]
# ## 15) Algorithmic Thinking
#
# Write a function that returns `True` if a list contains duplicates, otherwise `False`.
#
# Example:
# - `has_duplicates([1,2,3])` -> `False`
# - `has_duplicates([1,2,2,3])` -> `True`

# %%
def has_duplicates(lst):
    """Return True if lst contains duplicates, else False."""
    # TODO: implement
    pass

# %%
# Quick checks (optional)
# print(has_duplicates([1,2,3]))     # False
# print(has_duplicates([1,2,2,3]))   # True

# %% [markdown]
# ---
# ### End of Exam
# Make sure you've saved your notebook before submitting.
